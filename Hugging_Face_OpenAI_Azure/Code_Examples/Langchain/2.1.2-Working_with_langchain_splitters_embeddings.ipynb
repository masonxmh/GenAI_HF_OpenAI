# %%
import langchain
import langchain_core
import langchain_text_splitters

print(langchain.__version__)
print(langchain_core.__version__)
# Out:
# 1.2.3
# 1.3.0

# %%
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter,SentenceTransformersTokenTextSplitter
)

# %%
#Character-based splitter
text = """Hopefully, you’ve seen the pattern that most
decision-making requires multiple data points and
types to make decisions. AI agents are replacing
manual data stitching with automated, accurate
insights — boosting productivity and enabling faster
strategic decisions that ultimately will help unlock
new revenue opportunities. Here is one thing to keep
in mind as you start the journey to give employees
a decision intelligence agent: delivering accurate
answers while ensuring data privacy becomes
increasingly complex as more data sources are
connected and more AI agents are built on top of
them. To address this from the start, it's important
to evaluate solutions with a platform mindset where
shared data governance, processing and retrieval
resources drive cost-efficiencies."""

# %%
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=10,
    chunk_overlap=0,
)
chunks = splitter.split_text(text)
# Out:
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10

# %%
type(chunks)
# Out:
# list

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions
# 1 AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities
# 2 Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them
# 3 To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies

# %%
#Recursive splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=15,
    chunk_overlap=5,
)
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully,
# 1 you’ve seen
# 2 seen the
# 3 the pattern
# 4 that most
# 5 decision-makin
# 6 making
# 7 requires
# 8 multiple data
# 9 data points
# 10 and
# 11 types to make
# 12 decisions. AI
# 13 AI agents are
# 14 are replacing
# 15 manual data
# 16 data stitching
# 17 with
# 18 automated,
# 19 accurate
# 20 insights —
# 21 — boosting
# 22 productivity
# 23 and enabling
# 24 faster
# 25 strategic
# 26 decisions that
# 27 ultimately
# 28 will help
# 29 help unlock
# 30 new revenue
# 31 opportunities.
# 32 Here is one
# 33 one thing to
# 34 to keep
# 35 in mind as you
# 36 you start the
# 37 the journey to
# 38 to give
# 39 give employees
# 40 a decision
# 41 intelligence
# 42 agent:
# 43 delivering
# 19 accurate
# 45 answers while
# 46 ensuring data
# 47 data privacy
# 48 becomes
# 49 increasingly
# 50 complex as
# 51 as more data
# 52 data sources
# 53 are
# 54 connected and
# 55 and more AI
# 13 AI agents are
# 57 are built on
# 58 on top of
# 59 them. To
# 60 To address
# 61 this from the
# 62 the start,
# 63 it's important
# 64 to evaluate
# 65 solutions with
# 66 with a
# 67 a platform
# 68 mindset where
# 69 shared data
# 70 governance,
# 71 processing and
# 72 and retrieval
# 73 resources
# 74 drive
# 75 cost-efficienc
# 76 ciencies.

# %%
#Recursive splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=7,
    chunk_overlap=0,
    separators=[" "]
)
chunks = splitter.split_text(text)

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully,
# 1  you’ve
# 2 seen
# 3 the
# 4  pattern
# 5 that
# 6  most
# decision-making
# 7  requires
# 8  multiple
# 9 data
# 10  points
# 11  and
# types
# 12 to
# 13 make
# 14  decisions.
# 15 AI
# 16  agents
# 17 are
# 18  replacing
# manual
# 9 data
# 20  stitching
# 21 with
# 22  automated,
# 23  accurate
# insights
# 24 —
# 25  boosting
# 26  productivity
# 27 and
# 28  enabling
# 29  faster
# strategic
# 30  decisions
# 5 that
# 32  ultimately
# 33 will
# 34 help
# 35  unlock
# new
# 36  revenue
# 37  opportunities.
# 38 Here
# 39 is one
# 40 thing
# 12 to
# 42  keep
# in
# 43 mind
# 44 as you
# 45 start
# 3 the
# 47  journey
# 12 to
# 49 give
# 50  employees
# a
# 51  decision
# 52  intelligence
# 53  agent:
# 54  delivering
# 55  accurate
# answers
# 56 while
# 57  ensuring
# 9 data
# 59  privacy
# 60  becomes
# increasingly
# 61  complex
# 62 as
# 63 more
# 9 data
# 65  sources
# 66  are
# connected
# 27 and
# 63 more
# 15 AI
# 16  agents
# 17 are
# 72 built
# 73 on top
# 74  of
# them.
# 75 To
# 76  address
# 77 this
# 78 from
# 3 the
# 80  start,
# 81 it's
# 82  important
# to
# 83  evaluate
# 84  solutions
# 85 with a
# 86  platform
# 87  mindset
# 88  where
# shared
# 9 data
# 90  governance,
# 91  processing
# 27 and
# 93  retrieval
# resources
# 94 drive
# 95  cost-efficiencies.

# %%
splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=150,
    chunk_overlap=10,
)
chunks = splitter.split_text(text)
# Out:
# Created a chunk of size 203, which is longer than the specified 150
# Created a chunk of size 272, which is longer than the specified 150

# %%
for i in chunks:
  print(chunks.index(i),i)
# Out:
# 0 Hopefully, you’ve seen the pattern that most
# decision-making requires multiple data points and
# types to make decisions
# 1 AI agents are replacing
# manual data stitching with automated, accurate
# insights — boosting productivity and enabling faster
# strategic decisions that ultimately will help unlock
# new revenue opportunities
# 2 Here is one thing to keep
# in mind as you start the journey to give employees
# a decision intelligence agent: delivering accurate
# answers while ensuring data privacy becomes
# increasingly complex as more data sources are
# connected and more AI agents are built on top of
# them
# 3 To address this from the start, it's important
# to evaluate solutions with a platform mindset where
# shared data governance, processing and retrieval
# resources drive cost-efficiencies

# %%
splitter = SentenceTransformersTokenTextSplitter(
    model_name="sentence-transformers/all-mpnet-base-v2",
    chunk_size=150,
    chunk_overlap=20,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 splitter = SentenceTransformersTokenTextSplitter(
#       2     model_name="sentence-transformers/all-mpnet-base-v2",
#       3     chunk_size=150,
#       4     chunk_overlap=20,
#       5 )
#
# File e:\github\GenAI_HF_OpenAI\Hugging_Face_OpenAI_Azure\Code_Examples\.venv\lib\site-packages\langchain_text_splitters\sentence_transformers.py:53, in SentenceTransformersTokenTextSplitter.__init__(self, chunk_overlap, model_name, tokens_per_chunk, model_kwargs, **kwargs)
#      47 if not _HAS_SENTENCE_TRANSFORMERS:
#      48     msg = (
#      49         "Could not import sentence_transformers python package. "
#      50         "This is needed in order to use SentenceTransformersTokenTextSplitter. "
#      51         "Please install it with `pip install sentence-transformers`."
#      52     )
# ---> 53     raise ImportError(msg)
#      55 self.model_name = model_name
#      56 self._model = SentenceTransformer(self.model_name, **(model_kwargs or {}))
#
# ImportError: Could not import sentence_transformers python package. This is needed in order to use SentenceTransformersTokenTextSplitter. Please install it with `pip install sentence-transformers`.
